# %% [markdown]
# Seminar 18.04
#
# Articles, bag of words, td-idf
#
# Регулярные выражения

# %%
import csv

next_text = []
with open('news.csv', 'r') as file:
    news = csv.DictReader(file)
    next_text = [line['text'] for line in news]

print(*next_text[:10], sep='\n')
# Out:
# В 1930-е годы Советский Союз охватила лихорадка — в десятилетие бурной индустриализации повсюду гремели сообщения о новых трудовых подвигах простого народа ради построения коммунизма и светлого будущего. Первым из них стал шахтер из Донбасса  Алексей Стаханов . 85 лет назад он установил рекорд по добыче угля за смену и на следующее утро проснулся знаменитым на весь мир. Его одаривали квартирами и машинами, возили по Союзу, он стал любимцем Сталина, однако в итоге не выдержал славы и спился. Фамилия Стаханова, которая дала название движению трудовиков, превратилась в нарицательную и продолжила существовать отдельно от него. Живая витрина коммунизма — в материале  «Ленты.ру» . История легенды советского труда началась на шахте «Центральная-Ирмино» в Донбассе. К 1935 году советские власти запустили вторую пятилетку и активно проводили политику ускоренной индустриализации, пытаясь по заветам Владимира Ленина догнать и перегнать развитые капиталистические страны, от которых безнадежно отстали в экономическом плане после распада Российской империи. Однако препятствием на этом пути была низкая производительность труда советских рабочих. Например, в угольной промышленности ее повышению мешал сам способ добычи: во-первых, многие продолжали рубить уголь по старинке с помощью обушка (кирки), хотя уже шло внедрение более эффективных пневматических молотков; во-вторых, шахтеры, находясь под землей, не могли безостановочно заниматься рубкой, постоянно отвлекаясь на укрепление сводов шахт. Такая проблема  существовала  и на шахте «Центральная-Ирмино» в Луганской области, которая регулярно не выполняла ежедневную норму добычи угля. Летом 1935 года у местного забойщика Андрея Стаханова возникла идея, как повысить производительность труда шахтеров. Он предложил эффективную систему разделения труда: забойщик занимался только рубкой угля, а работающие с ним в тандеме рабочие параллельно занимались исключительно укреплением свода шахты. Идея  понравилась  местному парторгу  Константину Петрову , который решил организовать установление рекорда. Он добился того, чтобы Стаханову позволили опробовать новый метод добычи, и начал тщательно готовиться к событию. Петров сам выбрал наиболее богатый углем участок, выделил в бригаду Стаханова двоих крепильщиков и двоих откатчиков угля и даже лично спустился в шахту, чтобы контролировать процесс работы и светить в забое. Присутствовать на смене также позвали редактора местной газеты, который должен был тут же зафиксировать историческое событие. Внушительный рекорд удалось установить с первой же попытки: в ночь с 30 на 31 августа 1935 года Стаханов за смену в 5 часов 45 минут нарубил 102 тонны угля при норме в 7 тонн, таким образом перевыполнив ее почти в 15 раз. По правилам того времени, добытый уголь должны были разделить на всю бригаду, однако рекорд отдали единолично Стаханову. Всесоюзная слава не заставила себя долго ждать: почти сразу же заметка о Стаханове появилась в «Правде» — главной газете страны, — и имя Стаханова погремело на весь Союз. При публикации заметки  произошла  досадная ошибка: журналисты, получив телеграмму от парткома шахты «Центральная-Ирмино», неверно написали имя героя. В сообщении говорилось, что автором рекорда является «А. Стаханов», и редакторы предположили, что «А.» означает «Алексей». Об ошибке стало известно почти сразу, однако менять имя было поздно: Стаханов уже стал всесоюзной знаменитостью под именем Алексей и привлек внимание советских властей, в том числе лично товарища Сталина. Именно последний нашел выход из ситуации: « Газета "Правда"  не ошибается», — пояснил Сталин и распорядился выдать рекордсмену паспорт на новое имя. Дочь Стаханова Виолетта позднее  отрицала , что отца когда-то звали Андреем. Причиной интереса политической элиты СССР самого высокого уровня к фигуре простого рабочего из Донбасса стала проблемная индустриализация страны. Дело в том, что Россия к началу Первой мировой войны (1914-1918) была аграрным государством. Хотя к 1913 году подданные империи  ...
# Лидии  из Москвы хватило одной поездки в Италию, чтобы влюбиться в эту страну. Пять лет назад она перебралась в Рим и поступила в университет. В рамках  цикла  материалов о россиянах, перебравшихся за границу,  «Лента.ру»  публикует ее рассказ о том, что она узнала об Италии и итальянцах. Я никогда не планировала уезжать из России и была равнодушна к путешествиям. Лет до 25 мой английский был на уровне London is the capital of Great Britain, не говоря уже о других иностранных языках. Но все изменилось, когда я первый раз приехала в Италию в мае 2011 года. Навсегда запомню это чувство: я стою на смотровой площадке карликового государства Сан-Марино и в состоянии какого-то восторженного оцепенения смотрю на залитые солнцем зеленые итальянские холмы и море на горизонте. Это был стандартный экскурсионный автобусный тур по Италии, поэтому всего через пару дней я оказалась в Риме. Там я поняла: это мой город, и мое место здесь. В 2012-м я начала учить итальянский с нуля, а летом 2013-го на целый месяц приехала в Рим в языковую школу. Я сняла комнату в тихом районе Остиенсе и, как выяснилось уже потом, совсем рядом со своим будущим университетом. Я ездила в школу на автобусе мимо здания ректората и с благоговением смотрела на него. Поступление в итальянский вуз казалось мне тогда чем-то из области фантастики. Однако когда я всерьез задалась вопросом о том, как же мне переехать в Италию, вариант с университетом, наоборот, оказался самым реальным из всех. В последний год жизни в Москве я работала в крупной медийной компании и параллельно занималась большим проектом на фрилансе, поэтому выходных почти не было. В августе я с огромным облегчением уволилась и уехала в полнейшую неизвестность. Впереди были вступительные экзамены в университет и никаких гарантий, что я их сдам. Но я-то, конечно, знала, что сдам, иначе просто и быть не могло. 31 августа 2015 года у меня началась совершенно новая жизнь. С московской окраины я переехала в самый центр Рима, в район Сан-Джованни, откуда до Колизея меньше получаса ходьбы. Это просто не укладывалось у меня в голове!  По российскому образованию я журналист, но при переезде я сразу отказалась от идеи поступать в магистратуру на журналистику в силу специфики профессии. Все-таки она привязана к языку, а итальянский мне не родной. Поэтому я решила начать все с нуля и поступила на бакалавриат по специальности «Языки и иностранные культуры» в университет Roma Tre.  Обучение в государственных вузах в Италии может быть как платным, так и бесплатным. Размер оплаты зависит от совокупного дохода семьи студента и наличия недвижимости. В моем университете суммы варьируются от символических 16 евро до двух тысяч евро в год. Учеба построена таким образом, что дает вам определенную степень свободы в выборе предметов и составлении учебного плана, но и ответственность полностью ложится на вас. Кроме того, существует довольно много организационных нюансов, о которых в секретариате университета не рассказывают, и вам придется самостоятельно читать о них в документах, регулирующих учебный процесс, или спрашивать в тематических форумах и группах в Facebook. Насколько легко или сложно будет учиться, зависит от выбранной специальности, вашего российского бэкграунда ну и, конечно, желания. Нормативный срок учебы составляет 3,5 года для бакалавриата и 2,5 — для магистратуры, но в действительности учиться в университете можно хоть всю жизнь. Главное — регулярно оплачивать обучение. Первые два года я продолжала удаленно работать на российское рекламное агентство. На втором году жизни в Риме добавилась подработка по выходным в ночном клубе в центре города. Бонусом к ней были захватывающие дух виды совершенно пустого ночного Рима. На третий год я начала работать с русским ивент-агентством, которое занимается проведением квестов, экскурсий, мастер-классов и организацией различных мероприятий в Италии. Часто работу находят через знакомых, потому что блат, который по-итальянски называют nepotismo, здесь развит еще сильнее, чем в Ро ...

# %%
import string
import re

with open('stopwords-ru.txt', 'r') as file:
    stop_words = {line.strip() for line in file}

def processing(line):
    line = line.lower()
    line = re.sub(f'[0-9{string.punctuation}»«—]+', '', line)
    # for sw in stop_words:
    #     line = line.replace(sw, '')
    return [word for word in line.split() if word not in stop_words]

processing(next_text[0])
# Out:
# ['годы',
#  'союз',
#  'охватила',
#  'лихорадка',
#  'десятилетие',
#  'бурной',
#  'индустриализации',
#  'повсюду',
#  'гремели',
#  'сообщения',
#  'новых',
#  'трудовых',
#  'подвигах',
#  'простого',
#  'народа',
#  'ради',
#  'построения',
#  'коммунизма',
#  'светлого',
#  'будущего',
#  'первым',
#  'шахтер',
#  'донбасса',
#  'алексей',
#  'стаханов',
#  'установил',
#  'рекорд',
#  'добыче',
#  'угля',
#  'смену',
#  'следующее',
#  'проснулся',
#  'знаменитым',
#  'одаривали',
#  'квартирами',
#  'машинами',
#  'возили',
#  'союзу',
#  'любимцем',
#  'сталина',
#  'итоге',
#  'выдержал',
#  'славы',
#  'спился',
#  'фамилия',
#  'стаханова',
#  'дала',
#  'название',
#  'движению',
#  'трудовиков',
#  'превратилась',
#  'нарицательную',
#  'продолжила',
#  'существовать',
#  'отдельно',
#  'живая',
#  'витрина',
#  'коммунизма',
#  'материале',
#  'лентыру',
#  'история',
#  'легенды',
#  'советского',
#  'труда',
#  'началась',
#  'шахте',
#  'центральнаяирмино',
#  'донбассе',
#  'советские',
#  'власти',
#  'запустили',
#  'вторую',
#  'пятилетку',
#  'активно',
#  'проводили',
#  'политику',
#  'ускоренной',
#  'индустриализации',
#  'пытаясь',
#  'заветам',
#  'владимира',
#  'ленина',
#  'догнать',
#  'перегнать',
#  'развитые',
#  'капиталистические',
#  'страны',
#  'безнадежно',
#  'отстали',
#  'экономическом',
#  'плане',
#  'распада',
#  'российской',
#  'империи',
#  'препятствием',
#  'пути',
#  'низкая',
#  'производительность',
#  'труда',
#  'советских',
#  'рабочих',
#  'например',
#  'угольной',
#  'промышленности',
#  'повышению',
#  'мешал',
#  'способ',
#  'добычи',
#  'вопервых',
#  'многие',
#  'продолжали',
#  'рубить',
#  'уголь',
#  'старинке',
#  'помощью',
#  'обушка',
#  'кирки',
#  'шло',
#  'внедрение',
#  'эффективных',
#  'пневматических',
#  'молотков',
#  'вовторых',
#  'шахтеры',
#  'находясь',
#  'землей',
#  'могли',
#  'безостановочно',
#  'заниматься',
#  'рубкой',
#  'постоянно',
#  'отвлекаясь',
#  'укрепление',
#  'сводов',
#  'шахт',
#  'проблема',
#  'существовала',
#  'шахте',
#  'центральнаяирмино',
#  'луганской',
#  'области',
#  'регулярно',
#  'выполняла',
#  'ежедневную',
#  'норму',
#  'добычи',
#  'угля',
#  'летом',
#  'местного',
#  'забойщика',
#  'андрея',
#  'стаханова',
#  'возникла',
#  'идея',
#  'повысить',
#  'производительность',
#  'труда',
#  'шахтеров',
#  'предложил',
#  'эффективную',
#  'систему',
#  'разделения',
#  'труда',
#  'забойщик',
#  'занимался',
#  'рубкой',
#  'угля',
#  'работающие',
#  'тандеме',
#  'рабочие',
#  'параллельно',
#  'занимались',
#  'исключительно',
#  'укреплением',
#  'свода',
#  'шахты',
#  'идея',
#  'понравилась',
#  'местному',
#  'парторгу',
#  'константину',
#  'петрову',
#  'решил',
#  'организовать',
#  'установление',
#  'рекорда',
#  'добился',
#  'стаханову',
#  'позволили',
#  'опробовать',
#  'метод',
#  'добычи',
#  'начал',
#  'тщательно',
#  'готовиться',
#  'событию',
#  'петров',
#  'выбрал',
#  'богатый',
#  'углем',
#  'участок',
#  'выделил',
#  'бригаду',
#  'стаханова',
#  'двоих',
#  'крепильщиков',
#  'двоих',
#  'откатчиков',
#  'угля',
#  'лично',
#  'спустился',
#  'шахту',
#  'контролировать',
#  'процесс',
#  'работы',
#  'светить',
#  'забое',
#  'присутствовать',
#  'смене',
#  'позвали',
#  'редактора',
#  'местной',
#  'газеты',
#  'зафиксировать',
#  'историческое',
#  'событие',
#  'внушительный',
#  'рекорд',
#  'удалось',
#  'установить',
#  'первой',
#  'попытки',
#  'августа',
#  'стаханов',
#  'смену',
#  'часов',
#  'минут',
#  'нарубил',
#  'тонны',
#  'угля',
#  'норме',
#  'тонн',
#  'таким',
#  'образом',
#  'перевыполнив',
#  'правилам',
#  'добытый',
#  'уголь',
#  'должны',
#  'разделить',
#  'бригаду',
#  'рекорд',
#  'отдали',
#  'единолично',
#  'стаханову',
#  'всесоюзная',
#  'слава',
#  'заставила',
#  'заметка',
#  'стаханове',
#  'появилась',
#  'правде',
#  'главной',
#  'газете',
#  'страны',
#  'стаханова',
#  'погремело',
#  'союз',
#  'публикации',
#  'заметки',
#  'произошла',
#  'досадная',
#  'ошибка',
#  'журналисты',
#  'получив',
#  'телеграмму',
#  'парткома',
#  'шахты',
#  'центральнаяирмино',
#  'неверно',
#  'написали',
#  'героя',
#  'сообщении',
#  'говорилось',
#  'автором',
#  'рекорда',
#  'является',
#  'стаханов',
#  'редакторы',
#  'предположили',
#  'означает',
#  'алексей',
#  'ошибке',
#  'стало',
#  'известно',
#  'менять',
#  'поздно',
#  'стаханов',
#  'всесоюзной',
#  'знаменитостью',
#  'именем',
#  'алексей',
#  'привлек',
#  'внимание',
#  'советских',
#  'властей',
#  'числе',
#  'лично',
#  'товарища',
#  'сталина',
#  'нашел',
#  'выход',
#  'ситуации',
#  'газета',
#  'ошибается',
#  'пояснил',
#  'сталин',
#  'распорядился',
#  'выдать',
#  'рекордсмену',
#  'паспорт',
#  'новое',
#  'дочь',
#  'стаханова',
#  'виолетта',
#  'позднее',
#  'отрицала',
#  'отца',
#  'когдато',
#  'звали',
#  'андреем',
#  'причиной',
#  'интереса',
#  'политической',
#  'элиты',
#  'ссср',
#  'высокого',
#  'уровня',
#  'фигуре',
#  'простого',
#  'рабочего',
#  'донбасса',
#  'стала',
#  'проблемная',
#  'индустриализация',
#  'страны',
#  'началу',
#  'первой',
#  'мировой',
#  'войны',
#  'аграрным',
#  'государством',
#  'подданные',
#  'империи',
#  'понемногу',
#  'начали',
#  'вовлекаться',
#  'труд',
#  'заводах',
#  'абсолютное',
#  'большинство',
#  'населения',
#  'продолжало',
#  'трудиться',
#  'сельском',
#  'хозяйстве',
#  'изза',
#  'октябрьской',
#  'революции',
#  'гражданской',
#  'войны',
#  'планомерного',
#  'искоренения',
#  'капиталистических',
#  'институтов',
#  'новые',
#  'власти',
#  'смогли',
#  'продолжить',
#  'индустриализацию',
#  'фактически',
#  'упустили',
#  'десятилетие',
#  'развития',
#  'сильнее',
#  'отстав',
#  'запада',
#  'российский',
#  'ввп',
#  'уровень',
#  'первой',
#  'мировой',
#  'войны',
#  'удалось',
#  'большевики',
#  'готовы',
#  'приступить',
#  'индустриализации',
#  'фактически',
#  'прихода',
#  'власти',
#  'находилась',
#  'жесточайшем',
#  'экономическом',
#  'кризисе',
#  'оголодавшее',
#  'военного',
#  'коммунизма',
#  'население',
#  'начало',
#  'восставать',
#  'нового',
#  'руководства',
#  'экономическом',
#  'фронте',
#  'попыткой',
#  'перехода',
#  'коммунизму',
#  'потерпели',
#  'поражение',
#  'серьезное',
#  'какое',
#  'поражение',
#  'нанесенное',
#  'колчаком',
#  'деникиным',
#  'констатировал',
#  'ленин',
#  'результате',
#  'советским',
#  'властям',
#  'пришлось',
#  'паузу',
#  'индустриализацией',
#  'восстановить',
#  'благосостояние',
#  'населения',
#  'усмирить',
#  'недовольство',
#  'временной',
#  'передышкой',
#  'стала',
#  'новая',
#  'экономическая',
#  'политика',
#  'нэп',
#  'объявленная',
#  'начале',
#  'х',
#  'годов',
#  'рамках',
#  'советское',
#  'руководство',
#  'частично',
#  'восстанавливало',
#  'капиталистические',
#  'инструменты',
#  'сельское',
#  'хозяйство',
#  'розничная',
#  'торговля',
#  'сфера',
#  'услуг',
#  'пищевая',
#  'легкая',
#  'промышленность',
#  'оказались',
#  'руках',
#  'частников',
#  'тяжелую',
#  'промышленность',
#  'банки',
#  'международную',
#  'торговлю',
#  'контролировало',
#  'государство',
#  'помочь',
#  'населению',
#  'восстановить',
#  'благосостояние',
#  'власти',
#  'ссср',
#  'отказались',
#  'силового',
#  'отбора',
#  'продуктов',
#  'крестьян',
#  'могли',
#  'вести',
#  'свободную',
#  'торговлю',
#  'излишками',
#  'богатеть',
#  'боясь',
#  'лишиться',
#  'нажитого',
#  'курс',
#  'новой',
#  'экономической',
#  'политики',
#  'оправдал',
#  'полной',
#  'мере',
#  'неполное',
#  'десятилетие',
#  'удалось',
#  'значительной',
#  'степени',
#  'восстановить',
#  'экономику',
#  'руин',
#  'власти',
#  'вновь',
#  'вернулись',
#  'идее',
#  'индустриализации',
#  'обеспокоены',
#  'развитием',
#  'капитализма',
#  'стране',
#  'лице',
#  'зажиточных',
#  'крестьян',
#  'большими',
#  'частными',
#  'хозяйствами',
#  'советская',
#  'политическая',
#  'верхушка',
#  'видела',
#  'угрозу',
#  'власти',
#  'конце',
#  'х',
#  'нэп',
#  'свернули',
#  'объявив',
#  'первую',
#  'пятилетку',
#  'приступив',
#  'индустриализации',
#  'подготовке',
#  'большого',
#  'экономического',
#  'скачка',
#  'профинансировать',
#  'рывок',
#  'точки',
#  'зрения',
#  'финансов',
#  'точки',
#  'зрения',
#  'рабочих',
#  'рук',
#  'должна',
#  'разбогатевшая',
#  'деревня',
#  'заполучить',
#  'капитал',
#  'покупки',
#  'рубежом',
#  'оборудования',
#  'заводов',
#  'союз',
#  'станков',
#  'производил',
#  'советское',
#  'руководство',
#  'начало',
#  'насильственно',
#  'отбирать',
#  'собственность',
#  'населения',
#  'высвободить',
#  'рабочие',
#  'руки',
#  'промышленных',
#  'предприятий',
#  'власти',
#  'сгоняли',
#  'крестьян',
#  'колхозы',
#  'неквалифицированная',
#  'рабочая',
#  'массово',
#  'покидала',
#  'деревню',
#  'изза',
#  'падения',
#  'уровня',
#  'жизни',
#  'бежала',
#  'города',
#  'экономическом',
#  'фронте',
#  'попыткой',
#  'перехода',
#  'коммунизму',
#  'потерпели',
#  'поражение',
#  'серьезное',
#  'какое',
#  'поражение',
#  'нанесенное',
#  'колчаком',
#  'деникиным',
#  'результате',
#  'изза',
#  'разрухи',
#  'сельском',
#  'хозяйстве',
#  'ссср',
#  'годы',
#  'рухнула',
#  'производительность',
#  'экономики',
#  'промышленность',
#  'пострадала',
#  'поскольку',
#  'работали',
#  'неквалифицированные',
#  'кадры',
#  'могли',
#  'быстро',
#  'наладить',
#  'производство',
#  'помимо',
#  'населению',
#  'ударил',
#  'голодомор',
#  'жертвами',
#  'стали',
#  'дефицит',
#  'товаров',
#  'обернулся',
#  'возвращением',
#  'ненавистной',
#  'карточной',
#  'системе',
#  'отмененной',
#  'военным',
#  'коммунизмом',
#  'итогам',
#  'первой',
#  'пятилетки',
#  'советские',
#  'власти',
#  'поняли',
#  'насильственное',
#  'изъятие',
#  'крестьян',
#  'товаров',
#  'произвели',
#  'принуждение',
#  'тяжелому',
#  'труду',
#  'обеспечить',
#  'высокую',
#  'производительность',
#  'необходимую',
#  'большого',
#  'скачка',
#  'запуская',
#  'вторую',
#  'пятилетку',
#  'середине',
#  'х',
#  'кремле',
#  'смягчили',
#  'политику',
#  'вернули',
#  'населению',
#  'право',
#  'личные',
#  'подсобные',
#  'хозяйства',
#  'власти',
#  'ссср',
#  'задумались',
#  'новых',
#  'способах',
#  'побудить',
#  'население',
#  'трудовым',
#  'подвигам',
#  'контексте',
#  'внимание',
#  'кремля',
#  'привлек',
#  'андрей',
#  'стаханов',
#  'власти',
#  'сделали',
#  'лицом',
#  'пропагандистской',
#  'кампании',
#  'сути',
#  'руководство',
#  'ссср',
#  'середине',
#  'х',
#  'решило',
#  'строить',
#  'класс',
#  'сытой',
#  'счастливой',
#  'рабочей',
#  'аристократии',
#  'рекламной',
#  'вывеской',
#  'стаханов',
#  'рекордсменам',
#  'производствах',
#  'власти',
#  'обещали',
#  'признание',
#  'обществе',
#  'привилегии',
#  'стаханов',
#  'ударную',
#  'смену',
#  'августа',
#  'получил',
#  'премию',
#  'размере',
#  'месячного',
#  'оклада',
#  'рекорда',
#  'шахтера',
#  'занесли',
#  'доску',
#  'почета',
#  'предоставили',
#  'квартиру',
#  'телефоном',
#  'личную',
#  'выездную',
#  'лошадь',
#  'именных',
#  'места',
#  'жены',
#  'кинопоказы',
#  'спектакли',
#  'писала',
#  'советская',
#  'зарубежная',
#  'пресса',
#  'стаханов',
#  'попал',
#  'обложку',
#  'журнала',
#  'time',
#  'любые',
#  'сомнения',
#  'установленном',
#  'рекорде',
#  'пленум',
#  'шахтпарткома',
#  'обещал',
#  'сурово',
#  'карать',
#  'пытается',
#  'клеветать',
#  'товарища',
#  'стаханова',
#  'рекорд',
#  'случайный',
#  'выдуманный',
#  'далее',
#  'партийным',
#  'комитетом',
#  'расценены',
#  'самые',
#  'злейшие',
#  'враги',
#  'выступающие',
#  'лучших',
#  'людей',
#  'шахты',
#  'нашей',
#  'страны',
#  'отдающих',
#  'выполнения',
#  'указаний',
#  'вождя',
#  'нашей',
#  'партии',
#  'товарища',
#  'сталина',
#  'полном',
#  'использовании',
#  'техники',
#  'говорилось',
#  'постановлении',
#  'пленума',
#  'угроза',
#  'звучала',
#  'сурово',
#  'начальника',
#  'шахты',
#  'сопротивлявшегося',
#  'инициативе',
#  'петрова',
#  'стаханова',
#  'апробации',
#  'нового',
#  'метода',
#  'работы',
#  'установления',
#  'рекорда',
#  'сослали',
#  'лагеря',
#  'примере',
#  'стаханова',
#  'кремле',
#  'демонстрировали',
#  'советском',
#  'государстве',
#  'легально',
#  'обогатиться',
#  'подняться',
#  'социальном',
#  'лифте',
#  'рабочий',
#  'прямо',
#  'шахты',
#  'попасть',
#  'ряды',
#  'политической',
#  'элиты',
#  'страны',
#  'продемонстрировать',
#  'работает',
#  'новая',
#  'система',
#  'стаханова',
#  'перевели',
#  'москву',
#  'поселили',
#  'элитном',
#  'доме',
#  'набережной',
#  'специальным',
#  'решением',
#  'политбюро',
#  'приняли',
#  'партию',
#  'кандидатского',
#  'стажа',
#  'отправили',
#  'учебу',
#  'московскую',
#  'промышленную',
#  'академию',
#  'сделали',
#  'депутатом',
#  'верховного',
#  'совета',
#  'выделили',
#  'личный',
#  'автомобиль',
#  'ударник',
#  'труда',
#  'превратился',
#  'чиновника',
#  'фамилия',
#  'стаханова',
#  'зажила',
#  'отдельно',
#  'параллельно',
#  'существовали',
#  'национальный',
#  'герой',
#  'алексей',
#  'стаханов',
#  'которому',
#  'благоволил',
#  'сталин',
#  'простой',
#  'работяга',
#  'андрей',
#  'стаханов',
#  'волей',
#  'случая',
#  'попал',
#  'москву',
#  'пристрастился',
#  'алкоголю',
#  'василием',
#  'сталиным',
#  'устроил',
#  'пьяный',
#  'дебош',
#  'метрополе',
#  'побил',
#  'зеркала',
#  'сталин',
#  'прощал',
#  'проступки',
#  'любимцу',
#  'предупредил',
#  'прекратит',
#  'позорить',
#  'уважаемую',
#  'фамилию',
#  'придется',
#  'сменить',
#  'другую',
#  'итоге',
#  'андрей',
#  'стаханов',
#  'смерти',
#  'сталина',
#  'выслан',
#  'москвы',
#  'обратно',
#  'донбасс',
#  'запил',
#  'сильнее',
#  'конце',
#  'концов',
#  'умер',
#  'символ',
#  'советского',
#  'ударничества',
#  'алексей',
#  'стаханов',
#  'продолжал',
#  'успешно',
#  'существовать',
#  'роли',
#  'рекламного',
#  'щита',
#  'пропагандистская',
#  'кампания',
#  'центром',
#  'шахтерударник',
#  'дала',
#  'плоды',
#  'героистахановцы',
#  'мгновенно',
#  'стали',
#  'появляться',
#  'отраслях',
#  'советской',
#  'экономики',
#  'осенью',
#  'кузнец',
#  'горьковского',
#  'автозавода',
#  'александр',
#  'бусыгин',
#  'изготовил',
#  'смену',
#  'коленчатых',
#  'валов',
#  'вместо',
#  'вичуге',
#  'параллельно',
#  'стахановым',
#  'сестры',
#  'евдокия',
#  'мария',
#  'виноградовы',
#  'положили',
#  'начало',
#  'движению',
#  'многостаночниц',
#  'текстильной',
#  'промышленности',
#  'железной',
#  'дороге',
#  'машинист',
#  'петр',
#  'кривонос',
#  'предложил',
#  'водить',
#  'тяжелые',
#  'товарные',
#  'составы',
#  'удвоенной',
#  'скоростью',
#  'стахановского',
#  'движения',
#  'оборотная',
#  'появление',
#  'рабочей',
#  'аристократии',
#  'раздражало',
#  'членов',
#  'советского',
#  'общества',
#  'ударникам',
#  'рекорды',
#  'позволяли',
#  'значительно',
#  'повысить',
#  'уровень',
#  'жизни',
#  'средняя',
#  ...]

# %%
from natasha import Doc

with open('news.csv', 'r') as file:
    news = csv.DictReader(file)
    corpus = [Doc(line['text']) for line in news]

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

text = 'Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Рады. Парламентарии уверены, что признание Бандеры национальным героем поможет в борьбе с подрывной деятельностью против Украины в информационном поле, а также остановит «распространение мифов, созданных российской пропагандой». Степан Бандера (1909-1959) был одним из лидеров Организации украинских националистов, выступающей за создание независимого государства на территориях с украиноязычным населением. В 2010 году в период президентства Виктора Ющенко Бандера был посмертно признан Героем Украины, однако впоследствии это решение было отменено судом. '

doc = Doc(text)

for line in corpus:
    line.segment(segmenter)
    line.tag_morph(morph_tagger)

print(corpus[0])

stop_morph = {'SCONJ', 'PUNCT', 'ADP', 'COMP', 'NPRO', 'PREP', 'CONJ', 'PRED', 'PRCL', 'INTJ', 'CCONJ', 'PRON'}

if len(corpus[0].tokens) > 0:
    corpus[0].tokens[0].text = 'В'
# Out:
# Doc(text='В 1930-е годы Советский Союз охватила лихорадка —..., tokens=[...], sents=[...])

# %%
def preprocessing(line) :
    for token in line.tokens:
        token.lemmatize(morph_vocab)
    return [word.lemma for word in line.tokens if word.pos not in stop_morph]

corpus = list(map(preprocessing, corpus))

# %%
corpus[0]
# Out:
# ['1930-й',
#  'год',
#  'советский',
#  'союз',
#  'охватить',
#  'лихорадка',
#  'десятилетие',
#  'бурный',
#  'индустриализация',
#  'повсюду',
#  'греметь',
#  'сообщение',
#  'новый',
#  'трудовой',
#  'подвиг',
#  'простой',
#  'народ',
#  'построение',
#  'коммунизм',
#  'светлый',
#  'будущее',
#  'первый',
#  'стать',
#  'шахтер',
#  'донбасс',
#  'алексей',
#  'стаханов',
#  '85',
#  'год',
#  'назад',
#  'установить',
#  'рекорд',
#  'добыча',
#  'уголь',
#  'смена',
#  'и',
#  'следующий',
#  'утро',
#  'проснуться',
#  'знаменитый',
#  'весь',
#  'мир',
#  'его',
#  'одаривать',
#  'квартира',
#  'машина',
#  'возить',
#  'союз',
#  'стать',
#  'любимец',
#  'сталин',
#  'однако',
#  'итог',
#  'не',
#  'выдержать',
#  'слава',
#  'спиться',
#  'фамилия',
#  'стаханов',
#  'дать',
#  'название',
#  'движение',
#  'трудовик',
#  'превратиться',
#  'нарицательный',
#  'продолжить',
#  'существовать',
#  'отдельно',
#  'живой',
#  'витрина',
#  'коммунизм',
#  'материал',
#  'лента',
#  'ру',
#  'история',
#  'легенда',
#  'советский',
#  'труд',
#  'начаться',
#  'шахта',
#  'центральный-ирмин',
#  'донбасс',
#  '1935',
#  'год',
#  'советский',
#  'власть',
#  'запустить',
#  'второй',
#  'пятилетка',
#  'активно',
#  'проводить',
#  'политика',
#  'ускоренный',
#  'индустриализация',
#  'пытаться',
#  'завет',
#  'владимир',
#  'ленин',
#  'догнать',
#  'перегнать',
#  'развить',
#  'капиталистический',
#  'страна',
#  'безнадежно',
#  'отстать',
#  'экономический',
#  'план',
#  'распад',
#  'российский',
#  'империя',
#  'однако',
#  'препятствие',
#  'этот',
#  'путь',
#  'быть',
#  'низкий',
#  'производительность',
#  'труд',
#  'советский',
#  'рабочий',
#  'например',
#  'угольный',
#  'промышленность',
#  'ее',
#  'повышение',
#  'мешать',
#  'сам',
#  'способ',
#  'добыча',
#  'во-первых',
#  'многие',
#  'продолжать',
#  'рубить',
#  'уголь',
#  'старинка',
#  'помощь',
#  'обушок',
#  'кирка',
#  'уже',
#  'идти',
#  'внедрение',
#  'более',
#  'эффективный',
#  'пневматический',
#  'молоток',
#  'во-вторых',
#  'шахтер',
#  'находиться',
#  'земля',
#  'не',
#  'мочь',
#  'безостановочно',
#  'заниматься',
#  'рубка',
#  'постоянно',
#  'отвлекаться',
#  'укрепление',
#  'свод',
#  'шахта',
#  'такой',
#  'проблема',
#  'существовать',
#  'и',
#  'шахта',
#  'центральный-ирмин',
#  'луганский',
#  'область',
#  'регулярно',
#  'не',
#  'выполнять',
#  'ежедневный',
#  'норма',
#  'добыча',
#  'уголь',
#  'лето',
#  '1935',
#  'год',
#  'местный',
#  'забойщик',
#  'андрей',
#  'стаханов',
#  'возникнуть',
#  'идея',
#  'как',
#  'повысить',
#  'производительность',
#  'труд',
#  'шахтер',
#  'предложить',
#  'эффективный',
#  'система',
#  'разделение',
#  'труд',
#  'забойщик',
#  'заниматься',
#  'только',
#  'рубка',
#  'уголь',
#  'работать',
#  'тандем',
#  'рабочий',
#  'параллельно',
#  'заниматься',
#  'исключительно',
#  'укрепление',
#  'свод',
#  'шахта',
#  'идея',
#  'понравиться',
#  'местный',
#  'парторг',
#  'константин',
#  'петров',
#  'решить',
#  'организовать',
#  'установление',
#  'рекорд',
#  'добиться',
#  'стаханов',
#  'позволить',
#  'опробовать',
#  'новый',
#  'метод',
#  'добыча',
#  'начать',
#  'тщательно',
#  'готовиться',
#  'событие',
#  'петров',
#  'сам',
#  'выбрать',
#  'наиболее',
#  'богатый',
#  'уголь',
#  'участок',
#  'выделить',
#  'бригада',
#  'стаханов',
#  'двое',
#  'крепильщик',
#  'двое',
#  'откатчик',
#  'уголь',
#  'даже',
#  'лично',
#  'спуститься',
#  'шахта',
#  'контролировать',
#  'процесс',
#  'работа',
#  'светить',
#  'забой',
#  'присутствовать',
#  'смена',
#  'также',
#  'позвать',
#  'редактор',
#  'местный',
#  'газета',
#  'должный',
#  'быть',
#  'тут',
#  'же',
#  'зафиксировать',
#  'исторический',
#  'событие',
#  'внушительный',
#  'рекорд',
#  'удаться',
#  'установить',
#  'первый',
#  'же',
#  'попытка',
#  'ночь',
#  '30',
#  '31',
#  'август',
#  '1935',
#  'год',
#  'стаханов',
#  'смена',
#  '5',
#  'час',
#  '45',
#  'минута',
#  'нарубить',
#  '102',
#  'тонна',
#  'уголь',
#  'норма',
#  '7',
#  'тонна',
#  'такой',
#  'образ',
#  'перевыполнить',
#  'почти',
#  '15',
#  'раз',
#  'правило',
#  'тот',
#  'время',
#  'добыть',
#  'уголь',
#  'должный',
#  'быть',
#  'разделить',
#  'весь',
#  'бригада',
#  'однако',
#  'рекорд',
#  'отдать',
#  'единолично',
#  'стаханов',
#  'всесоюзный',
#  'слава',
#  'не',
#  'заставить',
#  'долго',
#  'ждать',
#  'почти',
#  'сразу',
#  'же',
#  'заметка',
#  'стаханов',
#  'появиться',
#  'правда',
#  'главный',
#  'газета',
#  'страна',
#  'имя',
#  'стаханов',
#  'погреметь',
#  'весь',
#  'союз',
#  'публикация',
#  'заметка',
#  'произойти',
#  'досадный',
#  'ошибка',
#  'журналист',
#  'получить',
#  'телеграмма',
#  'партком',
#  'шахта',
#  'центральный-ирмин',
#  'неверно',
#  'написать',
#  'имя',
#  'герой',
#  'сообщение',
#  'говориться',
#  'автор',
#  'рекорд',
#  'являться',
#  'а',
#  'стаханов',
#  'редактор',
#  'предположить',
#  'а',
#  'означать',
#  'алексей',
#  'ошибка',
#  'стать',
#  'известный',
#  'почти',
#  'сразу',
#  'однако',
#  'менять',
#  'имя',
#  'быть',
#  'поздно',
#  'стаханов',
#  'уже',
#  'стать',
#  'всесоюзный',
#  'знаменитость',
#  'имя',
#  'алексей',
#  'и',
#  'привлечь',
#  'внимание',
#  'советский',
#  'власть',
#  'тот',
#  'число',
#  'лично',
#  'товарищ',
#  'сталин',
#  'именно',
#  'последний',
#  'найти',
#  'выход',
#  'ситуация',
#  'газета',
#  'правда',
#  'не',
#  'ошибаться',
#  'пояснить',
#  'сталин',
#  'распорядиться',
#  'выдать',
#  'рекордсмен',
#  'паспорт',
#  'новый',
#  'имя',
#  'дочь',
#  'стаханов',
#  'виолетта',
#  'поздний',
#  'отрицать',
#  'отец',
#  'когда-то',
#  'звать',
#  'андрей',
#  'причина',
#  'интерес',
#  'политический',
#  'элита',
#  'ссср',
#  'сам',
#  'высокий',
#  'уровень',
#  'фигура',
#  'простой',
#  'рабочий',
#  'донбасс',
#  'стать',
#  'проблемный',
#  'индустриализация',
#  'страна',
#  'дело',
#  'россия',
#  'начало',
#  'первый',
#  'мировой',
#  'война',
#  '1914-1918',
#  'быть',
#  'аграрный',
#  'государство',
#  '1913',
#  'год',
#  'поддать',
#  'империя',
#  'понемногу',
#  'начать',
#  'вовлекаться',
#  'труд',
#  'завод',
#  'абсолютный',
#  'большинство',
#  'население',
#  'продолжать',
#  'трудиться',
#  'сельский',
#  'хозяйство',
#  'октябрьский',
#  'революция',
#  '1917',
#  'гражданский',
#  'война',
#  '1917-1922',
#  'планомерный',
#  'искоренение',
#  'капиталистический',
#  'институт',
#  'новый',
#  'власть',
#  'не',
#  'только',
#  'не',
#  'смочь',
#  'продолжить',
#  'индустриализация',
#  'фактически',
#  'упустить',
#  'десятилетие',
#  'развитие',
#  'еще',
#  'сильный',
#  'отстать',
#  'запад',
#  'так',
#  '1918',
#  'год',
#  'российский',
#  'ввп',
#  'быть',
#  '50',
#  'процент',
#  'ниже',
#  '1913-м',
#  'уровень',
#  'быть',
#  'первый',
#  'мировой',
#  'война',
#  'удаться',
#  'выйти',
#  'только',
#  '1928',
#  'год',
#  'большевик',
#  'готовый',
#  'быть',
#  'приступить',
#  'индустриализация',
#  'фактически',
#  'сразу',
#  'приход',
#  'власть',
#  'однако',
#  'страна',
#  'находиться',
#  'жестокий',
#  'экономический',
#  'кризис',
#  'ее',
#  'оголодать',
#  'время',
#  'военный',
#  'коммунизм',
#  '1918-1921',
#  'население',
#  'уже',
#  'начать',
#  'восставать',
#  'новый',
#  'руководство',
#  'экономический',
#  'фронт',
#  'попытка',
#  'переход',
#  'коммунизм',
#  'потерпеть',
#  'поражение',
#  'более',
#  'серьезный',
#  'какой',
#  'бы',
#  'ни',
#  'быть',
#  'поражение',
#  'нанести',
#  'колчак',
#  'деникин',
#  'констатировать',
#  'ленин',
#  'результат',
#  'советский',
#  'власть',
#  'прийтись',
#  'взять',
#  'пауза',
#  'индустриализация',
#  'восстановить',
#  'благосостояние',
#  'население',
#  'усмирить',
#  'недовольство',
#  'такой',
#  'временной',
#  'передышка',
#  'стать',
#  'новый',
#  'экономический',
#  'политика',
#  'нэп',
#  '1921-1928',
#  'объявить',
#  'начало',
#  '1920-й',
#  'год',
#  'ее',
#  'рамка',
#  'советский',
#  'руководство',
#  'частично',
#  'восстанавливать',
#  'капиталистический',
#  'инструмент',
#  'сельский',
#  'хозяйство',
#  'розничный',
#  'торговля',
#  'сфера',
#  'услуга',
#  'пищевой',
#  'легкий',
#  'промышленность',
#  'оказаться',
#  'рука',
#  'частник',
#  'тот',
#  'время',
#  'тяжелый',
#  'промышленность',
#  'банк',
#  'международный',
#  'торговля',
#  'контролировать',
#  'государство',
#  'помочь',
#  'население',
#  'восстановить',
#  'благосостояние',
#  'власть',
#  'ссср',
#  'отказаться',
#  'силовой',
#  'отбор',
#  'продукт',
#  'крестьянин',
#  'теперь',
#  'мочь',
#  'вести',
#  'свободный',
#  'торговля',
#  'излишек',
#  'богатеть',
#  'не',
#  'бояться',
#  'лишиться',
#  'нажить',
#  'курс',
#  'новый',
#  'экономический',
#  'политика',
#  'оправдать',
#  'полный',
#  'мера',
#  'неполный',
#  'десятилетие',
#  'удаться',
#  'значительный',
#  'степень',
#  'восстановить',
#  'экономика',
#  'руина',
#  'власть',
#  'вновь',
#  'вернуться',
#  'идея',
#  'индустриализация',
#  'быть',
#  'обеспокоить',
#  'развитие',
#  'капитализм',
#  'страна',
#  'лицо',
#  'зажиточный',
#  'крестьянин',
#  'больший',
#  'частный',
#  'хозяйство',
#  'советский',
#  'политический',
#  'верхушка',
#  'видеть',
#  'угроза',
#  'свой',
#  'власть',
#  'конец',
#  '1920-й',
#  'нэп',
#  'свернуть',
#  'объявить',
#  'первый',
#  'пятилетка',
#  'приступить',
#  'индустриализация',
#  'подготовка',
#  'большой',
#  'экономический',
#  'скачок',
#  'профинансировать',
#  'рывок',
#  'точка',
#  'зрение',
#  'финансы',
#  'так',
#  'и',
#  'точка',
#  'зрение',
#  'рабочий',
#  'рука',
#  'должный',
#  'быть',
#  'разбогатеть',
#  'деревня',
#  'заполучить',
#  'капитал',
#  'покупка',
#  'рубеж',
#  'оборудование',
#  'завод',
#  'сам',
#  'союз',
#  'свой',
#  'станок',
#  'не',
#  'производить',
#  'советский',
#  'руководство',
#  'снова',
#  'начать',
#  'насильственно',
#  'отбирать',
#  'собственность',
#  'население',
#  'высвободить',
#  'рабочий',
#  'рука',
#  'промышленный',
#  'предприятие',
#  'власть',
#  'сгонять',
#  'крестьянин',
#  'колхоз',
#  'неквалифицированный',
#  'рабочий',
#  'сила',
#  'массово',
#  'покидать',
#  'деревня',
#  'падение',
#  'уровень',
#  'жизнь',
#  'бежать',
#  'город',
#  'экономический',
#  'фронт',
#  'попытка',
#  'переход',
#  'коммунизм',
#  'потерпеть',
#  'поражение',
#  'более',
#  'серьезный',
#  'какой',
#  'бы',
#  'ни',
#  'быть',
#  'поражение',
#  'нанести',
#  'колчак',
#  'деникин',
#  'результат',
#  'разруха',
#  'сельский',
#  'хозяйство',
#  'ссср',
#  '1929-1933',
#  'год',
#  'рухнуть',
#  'производительность',
#  'экономика',
#  'промышленность',
#  'также',
#  'пострадать',
#  'работать',
#  'неквалифицированный',
#  'кадр',
#  'не',
#  'мочь',
#  'быстро',
#  'наладить',
#  'производство',
#  'население',
#  'ударить',
#  'голодомор',
#  'жертва',
#  'стать',
#  'несколько',
#  'миллион',
#  'человек',
#  'дефицит',
#  'товар',
#  'обернуться',
#  'возвращение',
#  'ненавистный',
#  'карточный',
#  'система',
#  'отменить',
#  'военный',
#  'коммунизм',
#  'итог',
#  'первый',
#  'пятилетка',
#  'советский',
#  'власть',
#  'понять',
#  'насильственный',
#  'изъятие',
#  'крестьянин',
#  'товар',
#  'произвести',
#  'принуждение',
#  'тяжелый',
#  'труд',
#  'не',
#  'мочь',
#  'обеспечить',
#  'высокий',
#  'производительность',
#  'необходимый',
#  'большой',
#  'скачок',
#  'запускать',
#  'второй',
#  'пятилетка',
#  'середина',
#  '1930-й',
#  'кремль',
#  'смягчить',
#  'политика',
#  'вернуть',
#  'население',
#  'право',
#  'личный',
#  'подсобный',
#  'хозяйство',
#  'власть',
#  'ссср',
#  'задуматься',
#  'новый',
#  'способ',
#  'побудить',
#  'население',
#  'трудовой',
#  'подвиг',
#  'именно',
#  'этот',
#  'контекст',
#  'внимание',
#  'кремль',
#  'привлечь',
#  'андрей',
#  'стаханов',
#  'власть',
#  'сделать',
#  'лицо',
#  'свой',
#  'пропагандистский',
#  'кампания',
#  'суть',
#  'руководство',
#  'ссср',
#  'середина',
#  '1930-й',
#  'решить',
#  'строить',
#  'класс',
#  'сытый',
#  'счастливый',
#  'рабочий',
#  'аристократия',
#  'рекламный',
#  'вывеска',
#  'и',
#  'стать',
#  'стаханов',
#  'рекордсмен',
#  'производство',
#  'власть',
#  'обещать',
#  'деньга',
#  'признание',
#  'общество',
#  'привилегия',
#  'так',
#  'стаханов',
#  'свой',
#  'ударный',
#  'смена',
#  '30',
#  '31',
#  'август',
#  'получить',
#  'премия',
#  'размер',
#  'месячный',
#  'оклад',
#  'сразу',
#  'же',
#  'рекорд',
#  'имя',
#  'шахтер',
#  'занести',
#  'доска',
#  'почет',
#  'предоставить',
#  'квартира',
#  'телефон',
#  'личный',
#  'выездной',
#  'лошадь',
#  'два',
#  'именной',
#  'место',
#  'жена',
#  'весь',
#  'кинопоказ',
#  'спектакль',
#  'писать',
#  'не',
#  'только',
#  'советский',
#  'зарубежный',
#  'пресса',
#  'стаханов',
#  'попасть',
#  'обложка',
#  'журнал',
#  'time',
#  'любой',
#  'сомнение',
#  'установить',
#  'рекорд',
#  'пленум',
#  'шахтпартком',
#  'обещать',
#  'сурово',
#  'карать',
#  'весь',
#  'тот',
#  'пытаться',
#  'клеветать',
#  'товарищ',
#  'стаханов',
#  'его',
#  'рекорд',
#  'случайный',
#  'выдумать',
#  'так',
#  'далее',
#  'партийный',
#  'комитет',
#  'быть',
#  'расценить',
#  'самый',
#  'злой',
#  'враг',
#  'выступать',
#  'хороший',
#  'человек',
#  'шахта',
#  'наш',
#  'страна',
#  'отдавать',
#  'выполнение',
#  'указание',
#  'вождь',
#  'наш',
#  'партия',
#  'товарищ',
#  'сталин',
#  'полный',
#  'использование',
#  'техника',
#  'говориться',
#  'постановление',
#  'пленум',
#  'угроза',
#  'звучать',
#  'особенно',
#  'сурово',
#  'еще',
#  'и',
#  'потому',
#  'начальник',
#  'шахта',
#  'сопротивляться',
#  'инициатива',
#  'петров',
#  'стаханов',
#  'апробация',
#  'новый',
#  'метод',
#  'работа',
#  'установление',
#  'рекорд',
#  'сослать',
#  'лагерь',
#  'пример',
#  'стаханов',
#  'кремль',
#  'демонстрировать',
#  'советский',
#  'государство',
#  'можно',
#  'не',
#  'только',
#  'легально',
#  'обогатиться',
#  'подняться',
#  'социальный',
#  'лифт',
#  'теперь',
#  'рабочий',
#  ...]

# %%
corpus_uni = set()
for line in corpus:
    corpus_uni |= set(line)
