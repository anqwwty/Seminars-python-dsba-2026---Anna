# %% [markdown]
# Seminar 25.04
# Songs

# %%
import csv

songs = []

with open('data.csv', 'r') as file:
    for row in csv.DictReader(file):
        songs.append((row['artist_name'], row['track_name']))

# %%
songs[:10]
# Out:
# [('Diplo', 'Trippy Mane (ft. Project Pat)'),
#  ('Yelawolf', 'OMG!'),
#  ('Riff Raff', 'Hard 2 Find'),
#  ('Diplo', 'Still Get Like That (ft. Project Pat & Starrah)'),
#  ('Rumelis', 'ride me like a harley'),
#  ('Minzie', 'BLEED'),
#  ('AZERDK', 'Te Procuro na Cidade'),
#  ('Rumelis', 'come closer'),
#  ('Toni dos Anjos', 'Cupido Vagabundo'),
#  ('PsychoYP', 'LET’S GO!')]

# %%
# !pip3 install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import requests
URL = "https://genius.com/Dj-paul-omg-lyrics"
res = requests.get(URL)
print(res.text[:500])
# Out:
# <!doctype html>
# <html>
#   <head>
#     <meta itemprop="cf-country" content="RU">
#     <meta itemprop="long-tail-cache" content="XX">
#     <meta itemprop="cf-cache-status" content="STALE">
#     <meta itemprop="rendered-with-cache" content="false">
#     <meta itemprop="cf-latitude" content="55.75204">
#     <meta itemprop="cf-longitude" content="37.61781">
#
#     <title>DJ Paul – OMG! Lyrics | Genius Lyrics</title>
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta content='width=de

# %%
# !python3 -m pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(res.text, 'html.parser')
soup.find("h1").text
# Out:
# 'OMG!'

# %%
nash_text = soup.find("div", attrs = {"class" : "Lyrics__Container-sc-c1895f55-1"})
header = nash_text.find("div", attrs = {"class" : "LyricsHeader__Container-sc-347d044d-1"})
if header:
    header.decompose()
for i in nash_text:
    print(i.text)


def fetch_lyrics_page(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    nash_text = soup.find("div", attrs = {"class" : "Lyrics__Container-sc-c1895f55-1"})
    header = nash_text.find("div", attrs = {"class" : "LyricsHeader__Container-sc-347d044d-1"})
    if header:
        header.decompose()
    return [i.text for i in nash_text if i.text]


fetch_lyrics_page("https://genius.com/Eminem-rap-god-lyrics")
api_end_point = "https://api.genius.com/"
query_point = "search?q="


headers = {
    'Authorization': f'Bearer {Bearer}',
}
for i in songs:
    query = " ".join(i)
    response = requests.get(api_end_point + query_point + query, headers=headers)
    break

# %%
for i in soup.find("div", attrs= {"class" : ""})

# %%
import json
result = json.loads(response.text)
if res := result.get('response').get('hits'):
    print(fetch_lyrics_page("https://genius.com/"+res[0]["result"]["path"]))

soup.find_all("a")
